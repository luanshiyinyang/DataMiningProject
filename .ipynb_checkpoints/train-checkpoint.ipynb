# %%
# 定义DTW计算公式
def DTW(s1, s2):
    """
    计算s1和s2之间的距离
    使用曼哈顿距离，如果时间序列输入是二维的那么建议使用欧几里得距离
    """
    from numpy import array, zeros, argmin, inf, equal, ndim
    from sklearn.metrics.pairwise import manhattan_distances
    r, c = len(s1), len(s2)
    D0 = zeros((r+1,c+1))
    D0[0,1:] = inf
    D0[1:,0] = inf
    D1 = D0[1:,1:]
    #生成原始距离矩阵
    for i in range(r):
        for j in range(c):
            D1[i,j] = manhattan_distances(np.array(s1[i]).reshape(-1,1),np.array(s2[j]).reshape(-1,1))
    M = D1.copy()
    for i in range(r):
        for j in range(c):
            D1[i,j] += min(D0[i,j],D0[i,j+1],D0[i+1,j])
    #代码核心，动态计算最短距离
    i,j = array(D0.shape) - 2
    #最短路径
    p,q = [i],[j]
    while(i>0 or j>0):
        tb = argmin((D0[i,j],D0[i,j+1],D0[i+1,j]))
        if tb==0 :
            i-=1
            j-=1
        elif tb==1 :
            i-=1
        else:
            j-=1
        p.insert(0,i)
        q.insert(0,j)
        #原始距离矩阵M
        #匹配路径过程D1
        # Cost Matrix或者叫累积距离矩阵
        return D1[-1,-1]

# %%
# Out:
# 3.0

# %%
import pandas as pd
df_train = pd.read_csv('data/train.csv')
print(df_train.head())
df_test = pd.read_csv('data/test_data.csv')
# Out:
#    id         1         2         3         4         5         6         7  \
# 0   1  0.563650  1.069229 -0.837759 -1.122021  0.433296  0.770755 -0.477153
# 1   2  0.061333  0.058830  0.056952  0.068634  0.073433  0.072390  0.042975
# 2   3  0.035736  0.010964 -0.164872 -0.167714 -0.125075 -0.104771 -0.016650
# 3   4 -0.046700  0.060913  0.009340 -0.093400 -0.067817  0.022335  0.006091
# 4   5  0.162922 -0.377662  0.014457  0.565437 -0.203369 -0.511508  0.410961
#
#           8         9  ...        5992      5993      5994      5995  \
# 0 -0.588421  0.455224  ...   -0.050761  0.220506  0.036548 -0.097461
# 1 -0.007302 -0.026286  ...    0.061333  0.107437  0.104516  0.063419
# 2  0.151471  0.137258  ...    4.272044 -1.991455 -2.922208  1.937039
# 3 -0.076751 -0.032893  ...    0.095025 -0.000406  0.091776  0.074314
# 4  0.228546 -0.515244  ...   -0.093563 -0.263632  0.114517  0.209541
#
#        5996      5997      5998      5999      6000  label
# 0 -0.084060 -0.007716 -0.049949 -0.018274  0.021523      7
# 1 -0.014394 -0.048607 -0.009388  0.058830  0.129342      0
# 2  0.704156 -2.085667  0.203044  0.739892 -2.149829      9
# 3 -0.082842 -0.110050 -0.028020  0.025990 -0.050355      9
# 4 -0.184851 -0.075370  0.286211  0.005685 -0.223348      7
#
# [5 rows x 6002 columns]

# %%
print(df_test)
# Out:
#       id         1         2         3         4         5         6  \
# 0      1  0.034517  0.087715 -0.273297 -0.339489  0.187613  0.282231
# 1      2 -1.981709  0.483651  2.006886 -0.057258 -1.880593 -0.495427
# 526  0.096162  0.145704  0.025665  0.027127  0.084141  0.013482 -0.084954
# 527  0.016898  0.060707  0.089079  0.083029  0.056952  0.036508  0.049025
#
# [528 rows x 6001 columns]

# %%
y_train = pd.DataFrame()
y_train['label'] = df_train['label']
df_train.drop(columns='label', inplace=True)

# %%
def get_t(df):
    mean_list = []
    std_list = []
    x = pd.DataFrame()
    for i in range(len(df)):
        mean_list.append(np.mean(df.iloc[i][1:].values))
        std_list.append(np.std(df.iloc[i][1:].values))
    x['mean'] = mean_list
    x['std'] = std_list
    return x

# %%
x_train = get_t(df_train)
x_test = get_t(df_test)
print(x_train.head())
print(x_test.head())
# Out:
#        mean       std
# 0  0.005931  0.590241
# 1  0.015328  0.065734
# 2  0.004769  0.552622
# 3  0.005525  0.384236
# 4  0.014422  0.250737
#        mean       std
# 0  0.003489  0.537096
# 1  0.006061  0.809820
# 2  0.006581  0.361151
# 3  0.009584  0.063453
# 4  0.004482  0.152550

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
# Out:
# C:\Users\16957\Anaconda3\envs\data-analysis\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
rst = knn.predict(x_test)
result = pd.DataFrame()
result['id'] = df_test['id']
print(len(rst))
result['label'] = rst
result.to_csv('data/result.csv', index=False, encoding="utf-8")
# Out:
# 528

# %%
# 手写KNN计算分类结果，注意K=1对于时序数据分类有不错的效果
rst = []
for i in range(len(df_test)):
    value = DTW(df_test.iloc[i][1:].values, df_train.iloc[0][1:].values)
    value_index = 0
    for j in range(1, len(df_train)):
        now_value = DTW(df_test.iloc[i][1:].values, df_train.iloc[j][1:].values)
        if now_value < value:
            value = now_value
            value_index = j
    print("判断第{}个".format(i))
    rst.append(y_train['label'].values[values_index])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-60aa2a2fff77> in <module>
#       5     value_index = 0
#       6     for j in range(1, len(df_train)):
# ----> 7         now_value = DTW(df_test.iloc[i][1:].values, df_train.iloc[j][1:].values)
#       8         if now_value < value:
#       9             value = now_value
#
# <ipython-input-29-e7f196dddf0b> in DTW(s1, s2)
#      15     for i in range(r):
#      16         for j in range(c):
# ---> 17             D1[i,j] = manhattan_distances(np.array(s1[i]).reshape(-1,1),np.array(s2[j]).reshape(-1,1))
#      18     M = D1.copy()
#      19     for i in range(r):
#
# ~\Anaconda3\envs\data-analysis\lib\site-packages\sklearn\metrics\pairwise.py in manhattan_distances(X, Y, sum_over_features, size_threshold)
#     515
#     516     if sum_over_features:
# --> 517         return distance.cdist(X, Y, 'cityblock')
#     518
#     519     D = X[:, np.newaxis, :] - Y[np.newaxis, :, :]
#
# ~\Anaconda3\envs\data-analysis\lib\site-packages\scipy\spatial\distance.py in cdist(XA, XB, metric, *args, **kwargs)
#    2658             cdist_fn = getattr(_distance_wrap,
#    2659                                "cdist_%s_%s_wrap" % (metric_name, typ))
# -> 2660             cdist_fn(XA, XB, dm, **kwargs)
#    2661             return dm
#    2662
#
# KeyboardInterrupt:
